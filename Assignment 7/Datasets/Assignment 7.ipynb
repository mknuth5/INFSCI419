# %%
import pandas as pd

# %%
criteria = pd.read_csv("criteria.csv")
print(criteria['Team'].value_counts())
print(criteria['Type_of_System'].value_counts())
print(criteria['Q1'].value_counts())
print(criteria['Q2'].value_counts())
print(criteria['Q3'].value_counts())
print(criteria['Q4'].value_counts())
print(criteria['Q5'].value_counts())
# Out:
# blue      110
# green     110
# red       100
# yellow    100
# Name: Team, dtype: int64
# recomendation    215
# search           205
# Name: Type_of_System, dtype: int64
# 1    303
# 0    117
# Name: Q1, dtype: int64
# 1    284
# 0    136
# Name: Q2, dtype: int64
# 0    329
# 1     91
# Name: Q3, dtype: int64
# 0    342
# 1     78
# Name: Q4, dtype: int64
# 0    294
# 1    126
# Name: Q5, dtype: int64

# %%
external_links = pd.read_csv("external_links.csv")
external_links
# Out:
#     User_ID    Team       Timestamp      Link    Type
# 0      SK9V   green  11/11/19 19:26  homepage  search
# 1      SK9V   green  11/11/19 19:26   scholar  search
# 2      G9T5  yellow  11/11/19 19:26  homepage  search
# 3      NOSO  yellow  11/11/19 19:26   scholar  search
# 4      DU58   green  11/11/19 19:26  homepage  search
# 5      DU58   green  11/11/19 19:26   scholar  search
# 6      ES3R  yellow  11/11/19 19:26   scholar  search
# 7      DJEG  yellow  11/11/19 19:26  homepage  search
# 8      ES3R  yellow  11/11/19 19:26  homepage  search
# 9      ZCNM  yellow  11/11/19 19:27  homepage  search
# 10     ES3R  yellow  11/11/19 19:27   scholar  search
# 11     01UI   green  11/11/19 19:27  homepage  search
# 12     01UI   green  11/11/19 19:27   scholar  search
# 13     WOTF   green  11/11/19 19:27   scholar  search
# 14     SK9V   green  11/11/19 19:27   scholar  search
# 15     DU58   green  11/11/19 19:27   scholar  search
# ...

# %%
keywords_description = pd.read_csv("keywords_description.csv")
keywords_description
# Out:
#      JNMM   red  2019-11-11 19:26:23                 Deep learning    recom  \
# 0    2H6O   red  2019-11-11 19:26:58         Computer architecture    recom
# 1    OAEG  blue  2019-11-11 19:27:00                    Golden Age  details
# 2    2H6O   red  2019-11-11 19:27:04       Language identification    recom
# 3    2H6O   red  2019-11-11 19:27:11                Neural network    recom
# 4    ZUMP  blue  2019-11-11 19:27:16          Transactional memory  details
# 5    OJWB   red  2019-11-11 19:27:22                   Fuzzy logic  details
# 6    ZUMP  blue  2019-11-11 19:27:27        Instruction scheduling  details
# 7    45UW  blue  2019-11-11 19:27:39              Machine learning    recom
# 8    OAEG  blue  2019-11-11 19:27:42          Programming language  details
# 9    2H6O   red  2019-11-11 19:27:42               Embedded system  details
# 10   OH12   red  2019-11-11 19:27:45              Machine learning    recom
# ...

# %%
post_study_survey = pd.read_csv("post_study_survey.csv")
post_study_survey
# Out:
#    User_ID    team            timestamp  Q1_search  Q1_recome  Q2_search  \
# 0     JNMM     red  2019-11-11 19:33:04          6          4          4
# 1     ROGI    blue  2019-11-11 19:34:11        100        100        100
# 2     SK9V   green  2019-11-11 19:35:08         30         30        100
# 3     BBRP    blue  2019-11-11 19:37:14         29         13          4
# 4     OAEG    blue  2019-11-11 19:37:58         39         26         26
# 5     OJWB     red  2019-11-11 19:38:24         32         31        100
# 6     NOSO  yellow  2019-11-11 19:39:06        100        100        100
# 7     DU58   green  2019-11-11 19:39:24         51         34         48
# 8     ES3R  yellow  2019-11-11 19:39:27         21         33         19
# 9     WOTF   green  2019-11-11 19:39:38         23         13         30
# 10    QDRT   green  2019-11-11 19:39:54         72         86         87
# 11    01UI   green  2019-11-11 19:40:37         45         44         44
# ...

# %%
post_task_recommender = pd.read_csv("post_task_recommender.csv")
post_task_recommender
# Out:
#    User_ID    team            timestamp  Q1  Q2  Q3  Q4  Q5  Q6  Q7  ...  Q11  \
# 0     01UI   green  2019-11-11 19:32:58   5   4   4   3   2   4   4  ...    3
# 1     2H6O     red  2019-11-11 19:39:37   5   3   4   2   4   1   4  ...    3
# 2     45UW    blue  2019-11-11 19:43:29   4   3   3   4   4   4   3  ...    3
# 3     5ITM   green  2019-11-11 19:34:57   4   2   4   3   4   3   4  ...    3
# 4     5MGY  yellow  2019-11-11 19:33:35   4   3   3   4   4   3   5  ...    3
# 5     801Z     red  2019-11-11 19:33:37   3   4   3   3   3   3   3  ...    3
# 6     8IVJ  yellow  2019-11-11 19:38:27   5   5   5   5   5   5   5  ...    5
# 7     9HVH     red  2019-11-11 19:39:12   4   3   4   3   4   4   5  ...    2
# 8     9P3N   green  2019-11-11 19:37:29   3   2   4   2   5   1   3  ...    3
# 9     BBRP    blue  2019-11-11 19:32:32   2   2   2   3   3   3   3  ...    2
# 10    C2MH     red  2019-11-11 19:38:26   5   2   4   5   4   4   4  ...    2
# ...
